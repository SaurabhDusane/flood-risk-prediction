# %% [markdown]
# # 02 - Data Preprocessing
#
# **Urban Flood Risk Prediction - CSE 572**
#
# This notebook handles data preprocessing including cleaning, scaling, and train-test splitting.

# %%
import sys
sys.path.append('..')

from src.data_preprocessing import load_data, preprocess_data, save_processed_data
from src.config import FEATURE_COLUMNS, TARGET_COLUMN

print("Modules loaded successfully!")

# %%
# Load raw data
train_df, test_df = load_data()

# %%
# Preprocess data
data = preprocess_data(train_df, test_df, scale=True)

# %%
# Display preprocessed data info
print(f"X_train shape: {data['X_train'].shape}")
print(f"X_val shape: {data['X_val'].shape}")
print(f"y_train shape: {data['y_train'].shape}")
print(f"y_val shape: {data['y_val'].shape}")

# %%
# Save processed data
save_processed_data(data)
print("\n✅ Preprocessing complete!")
